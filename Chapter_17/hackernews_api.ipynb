# %%
import requests
from operator import itemgetter

url='https://hacker-news.firebaseio.com/v0/topstories.json'
r=requests.get(url)
print("Status code:",r.status_code)

submission_ids=r.json()
#print(submission_ids)
submission_dicts=[ ]
for submission_id in submission_ids[:30]:
    url=f"https://hacker-news.firebaseio.com/v0/item/{submission_id}.json"
    submission_r=requests.get(url)
    print(submission_r.status_code)
    response_dict=submission_r.json()
    submission_dict={
        'title':response_dict['title'],
        'link':f"https://news.ycombinator.com/item?id={submission_id}",
        'comments':response_dict.get('descendants',0),
    }
    submission_dicts.append(submission_dict)

submission_dicts=sorted(submission_dicts,key=itemgetter('comments'),reverse=True)
for submission_dict in submission_dicts:
    print(f"\nTitle:{submission_dict['title']}")
    print(f"Discussion link:{submission_dict['link']}")
    print(f"Comments:{submission_dict['comments']}")
# Out:
# Status code: 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
#
# Title:The Fed says this is a cube of $1M. They're off by half a million
# Discussion link:https://news.ycombinator.com/item?id=44435484
# Comments:395
#
# Title:I built something that changed my friend group's social fabric
# Discussion link:https://news.ycombinator.com/item?id=44403988
# Comments:240
#
# Title:Ask HN: Who is hiring? (July 2025)
# Discussion link:https://news.ycombinator.com/item?id=44434576
# Comments:232
#
# Title:Ask HN: Who wants to be hired? (July 2025)
# Discussion link:https://news.ycombinator.com/item?id=44434574
# Comments:187
#
# Title:Show HN: Spegel, a Terminal Browser That Uses LLMs to Rewrite Webpages
# Discussion link:https://news.ycombinator.com/item?id=44433409
# Comments:146
#
# Title:Figma Files Registration Statement for Proposed Initial Public Offering
# Discussion link:https://news.ycombinator.com/item?id=44437316
# Comments:106
#
# Title:Ask HN: Freelancer? Seeking freelancer? (July 2025)
# Discussion link:https://news.ycombinator.com/item?id=44434575
# Comments:105
#
# Title:Australians to face age checks from search engines
# Discussion link:https://news.ycombinator.com/item?id=44439058
# Comments:98
#
# Title:Effectiveness of trees in reducing temperature, outdoor heat exposure in Vegas
# Discussion link:https://news.ycombinator.com/item?id=44437948
# Comments:82
#
# Title:Fakespot shuts down today after 9 years of detecting fake product reviews
# Discussion link:https://news.ycombinator.com/item?id=44437712
# Comments:75
#
# Title:Building a Personal AI Factory
# Discussion link:https://news.ycombinator.com/item?id=44438065
# Comments:67
#
# Title:Feasibility study of a mission to Sedna - Nuclear propulsion and solar sailing
# Discussion link:https://news.ycombinator.com/item?id=44434062
# Comments:66
#
# Title:OpenFLOW – Quickly make beautiful infrastructure diagrams local to your machine
# Discussion link:https://news.ycombinator.com/item?id=44431178
# Comments:66
#
# Title:Show HN: Jobs by Referral: Find jobs in your LinkedIn network
# Discussion link:https://news.ycombinator.com/item?id=44433386
# Comments:53
#
# Title:Swearing as a Response to Pain: Assessing Effects of Novel Swear Words
# Discussion link:https://news.ycombinator.com/item?id=44412480
# Comments:50
#
# Title:Code⇄GUI bidirectional editing via LSP
# Discussion link:https://news.ycombinator.com/item?id=44435716
# Comments:40
#
# Title:Hilbert's sixth problem: derivation of fluid equations via Boltzmann's theory
# Discussion link:https://news.ycombinator.com/item?id=44439242
# Comments:35
#
# Title:Show HN: Core – open source memory graph for LLMs – shareable, user owned
# Discussion link:https://news.ycombinator.com/item?id=44435500
# Comments:29
#
# Title:Converting a large mathematical software package written in C++ to C++20 modules
# Discussion link:https://news.ycombinator.com/item?id=44433899
# Comments:25
#
# Title:All Good Editors Are Pirates: In Memory of Lewis H. Lapham
# Discussion link:https://news.ycombinator.com/item?id=44413957
# Comments:11
#
# Title:The wanton destruction of a creative-tech era
# Discussion link:https://news.ycombinator.com/item?id=44437015
# Comments:10
#
# Title:The Hoyle State (2021)
# Discussion link:https://news.ycombinator.com/item?id=44436555
# Comments:8
#
# Title:Show HN: A local secrets manager with easy backup
# Discussion link:https://news.ycombinator.com/item?id=44411586
# Comments:7
#
# Title:Show HN: I made a 2D game engine in Dart
# Discussion link:https://news.ycombinator.com/item?id=44404447
# Comments:5
#
# Title:Graph Theory Applications in Video Games
# Discussion link:https://news.ycombinator.com/item?id=44403547
# Comments:4
#
# Title:The Roman Roads Research Association
# Discussion link:https://news.ycombinator.com/item?id=44437758
# Comments:3
#
# Title:Why Do Swallows Fly to the Korean DMZ?
# Discussion link:https://news.ycombinator.com/item?id=44404243
# Comments:2
#
# Title:Soldier's wrist purse discovered at Roman legionary camp
# Discussion link:https://news.ycombinator.com/item?id=44406401
# Comments:2
#
# Title:Victory Shoot: Hanemono in Toy Form
# Discussion link:https://news.ycombinator.com/item?id=44413461
# Comments:0
#
# Title:Cua (YC X25) is hiring an engineer
# Discussion link:https://news.ycombinator.com/item?id=44435910
# Comments:0

# %%
print(submission_dicts[0])
# Out:
# {'title': "The Fed says this is a cube of $1M. They're off by half a million", 'link': 'https://news.ycombinator.com/item?id=44435484', 'comments': 395}

# %%
import pygal
from pygal.style import LightColorizedStyle as LCS,LightenStyle as LS

names,plot_dicts=[],[]
article_links, comment_counts, hover_texts = [], [], []
for submission_dict in submission_dicts:
    names.append(submission_dict['title'])
    plot_dict={
        'value':submission_dict['comments'],
        'label':submission_dict['title'],
        'xlink':submission_dict['link'],
    }
    plot_dicts.append(plot_dict)
    
    my_style=LS('#333366',base_style=LCS)
    my_config=pygal.Config()
    my_config.x_label_rotation=45
    my_config.show_legend=False
    my_config.title_font_size=24
    my_config.label_font_size=14
    my_config.major_label_font_size=18
    my_config.truncate_label=15
    my_config.show_y_guides=False
    my_config.width=1000
    
    chart=pygal.Bar(my_config,style=my_style)
    chart.title='Most active Discussions on Hacker News'
    chart.x_labels=names
    chart.add('',plot_dicts)
    chart.render_to_file('/Users/yaswanth/Downloads/Data_Visualization/Chapter_17/hacker_news.svg')
